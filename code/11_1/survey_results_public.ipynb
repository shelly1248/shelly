# %%
import pandas as pd
filename = r'C:\\sqlite\\mysql\\code\\11_1\\survey_results_public.csv'
df = pd.read_csv(filename)
df.head(5)
# Out:
#    ResponseId                                         MainBranch  \
# 0           1                     I am a developer by profession
# 1           2             I am a student who is learning to code
# 2           3  I am not primarily a developer, but I write co...
# 3           4                     I am a developer by profession
# 4           5                     I am a developer by profession
#
#                                           Employment  \
# 0  Independent contractor, freelancer, or self-em...
# 1                                 Student, full-time
# 2                                 Student, full-time
# 3                                 Employed full-time
# 4  Independent contractor, freelancer, or self-em...
#
#                                              Country US_State UK_Country  \
# 0                                           Slovakia      NaN        NaN
# 1                                        Netherlands      NaN        NaN
# ...

# %%
df[['Age','Country','LanguageHaveWorkedWith','LearnCode']]
# Out:
#                    Age                                            Country  \
# 0      25-34 years old                                           Slovakia
# 1      18-24 years old                                        Netherlands
# 2      18-24 years old                                 Russian Federation
# 3      35-44 years old                                            Austria
# 4      25-34 years old  United Kingdom of Great Britain and Northern I...
# ...                ...                                                ...
# 83434  25-34 years old                           United States of America
# 83435  18-24 years old                                              Benin
# 83436  25-34 years old                           United States of America
# 83437  25-34 years old                                             Canada
# 83438  18-24 years old                                             Brazil
#
#                               LanguageHaveWorkedWith  \
# ...

# %%
df['Age'].value_counts()
# Out:
# Age
# 25-34 years old       32568
# 18-24 years old       20993
# 35-44 years old       15183
# 45-54 years old        5472
# Under 18 years old     5376
# 55-64 years old        1819
# Prefer not to say       575
# 65 years or older       421
# Name: count, dtype: int64

# %%
df['Age'].drop_duplicates()
# Out:
# 0         25-34 years old
# 1         18-24 years old
# 3         35-44 years old
# 6       Prefer not to say
# 14        45-54 years old
# 15     Under 18 years old
# 47      65 years or older
# 105       55-64 years old
# 149                   NaN
# Name: Age, dtype: object

# %%
df.groupby(['Age'])

# %%
size_by_age = df.groupby(["Age"]).size()
size_by_age
# Out:
# Age
# 18-24 years old       20993
# 25-34 years old       32568
# 35-44 years old       15183
# 45-54 years old        5472
# 55-64 years old        1819
# 65 years or older       421
# Prefer not to say       575
# Under 18 years old     5376
# dtype: int64

# %%
df.groupby(['Country'])

# %%
size_by_Country = df.groupby(["Country"]).size()
size_by_Country.sort_values(ascending=False)
# Out:
# Country
# United States of America                                15288
# India                                                   10511
# Germany                                                  5625
# United Kingdom of Great Britain and Northern Ireland     4475
# Canada                                                   3012
#                                                         ...
# Liechtenstein                                               1
# Papua New Guinea                                            1
# Dominica                                                    1
# Saint Kitts and Nevis                                       1
# Saint Vincent and the Grenadines                            1
# Length: 181, dtype: int64

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(10,10)) ## 캔버스 생성
fig.set_facecolor('white') ## 캔버스 색상 설정
ax = fig.add_subplot() ## 그림 뼈대(프레임) 생성
 
ax.plot(size_by_age)
plt.xticks(rotation=45)
# Out:
# ([0, 1, 2, 3, 4, 5, 6, 7],
#  [Text(0, 0, '18-24 years old'),
#   Text(1, 0, '25-34 years old'),
#   Text(2, 0, '35-44 years old'),
#   Text(3, 0, '45-54 years old'),
#   Text(4, 0, '55-64 years old'),
#   Text(5, 0, '65 years or older'),
#   Text(6, 0, 'Prefer not to say'),
#   Text(7, 0, 'Under 18 years old')])

# %%
size_by_age.plot.bar()
plt.xticks(rotation=45)
# Out:
# (array([0, 1, 2, 3, 4, 5, 6, 7]),
#  [Text(0, 0, '18-24 years old'),
#   Text(1, 0, '25-34 years old'),
#   Text(2, 0, '35-44 years old'),
#   Text(3, 0, '45-54 years old'),
#   Text(4, 0, '55-64 years old'),
#   Text(5, 0, '65 years or older'),
#   Text(6, 0, 'Prefer not to say'),
#   Text(7, 0, 'Under 18 years old')])

# %%
size_by_age.plot.barh()
plt.xticks(rotation=45)
# Out:
# (array([    0.,  5000., 10000., 15000., 20000., 25000., 30000., 35000.]),
#  [Text(0.0, 0, '0'),
#   Text(5000.0, 0, '5000'),
#   Text(10000.0, 0, '10000'),
#   Text(15000.0, 0, '15000'),
#   Text(20000.0, 0, '20000'),
#   Text(25000.0, 0, '25000'),
#   Text(30000.0, 0, '30000'),
#   Text(35000.0, 0, '35000')])

# %%
size_by_age = size_by_age[['Under 18 years old','18-24 years old', '25-34 years old', '35-44 years old',
       '45-54 years old', '55-64 years old', '65 years or older','Prefer not to say']]

# %%
size_by_age.plot.bar()
plt.xticks(rotation=45)
# Out:
# (array([0, 1, 2, 3, 4, 5, 6, 7]),
#  [Text(0, 0, 'Under 18 years old'),
#   Text(1, 0, '18-24 years old'),
#   Text(2, 0, '25-34 years old'),
#   Text(3, 0, '35-44 years old'),
#   Text(4, 0, '45-54 years old'),
#   Text(5, 0, '55-64 years old'),
#   Text(6, 0, '65 years or older'),
#   Text(7, 0, 'Prefer not to say')])

# %%
# reindxed_size_by_age = size_by_age.reindex(index=[
#     'Prefer not to say',
#     '65 years or older',
#     '55-64 years old',
#     '45-54 years old', 
#     '35-44 years old',
#     '25-34 years old', 
#     '18-24 years old', 
#     'Under 18 years old' 
#     ]) 재색인하기

# %%
size_by_Country.plot.pie()
# Out:
# <Axes: >

# %%
size_by_Country.plot.pie(figsize=(10, 10))
# Out:
# <Axes: >

# %%
size_by_Country_ten = size_by_Country.sort_values(ascending=False)
size_by_Country_ten[:20].plot.pie()
# Out:
# <Axes: >

# %%
df[['LanguageHaveWorkedWith']]
# Out:
#                               LanguageHaveWorkedWith
# 0      C++;HTML/CSS;JavaScript;Objective-C;PHP;Swift
# 1                                  JavaScript;Python
# 2                           Assembly;C;Python;R;Rust
# 3                              JavaScript;TypeScript
# 4                     Bash/Shell;HTML/CSS;Python;SQL
# ...                                              ...
# 83434                             Clojure;Kotlin;SQL
# 83435                                            NaN
# 83436                             Groovy;Java;Python
# 83437           Bash/Shell;JavaScript;Node.js;Python
# 83438         Delphi;Elixir;HTML/CSS;Java;JavaScript
#
# [83439 rows x 1 columns]

# %%
df['LanguageHaveWorkedWith'] = df['LanguageHaveWorkedWith'].str.strip()

# %%
languages = df['LanguageHaveWorkedWith'].str.split(";")
# 리스트 항목을 행으로 나누기
exploded_languages = languages.explode()

# 데이터 확인
exploded_languages
# Out:
# 0                C++
# 0           HTML/CSS
# 0         JavaScript
# 0        Objective-C
# 0                PHP
#             ...
# 83438         Delphi
# 83438         Elixir
# 83438       HTML/CSS
# 83438           Java
# 83438     JavaScript
# Name: LanguageHaveWorkedWith, Length: 443642, dtype: object

# %%
exploded_languages
# Out:
# 0                C++
# 0           HTML/CSS
# 0         JavaScript
# 0        Objective-C
# 0                PHP
#             ...
# 83438         Delphi
# 83438         Elixir
# 83438       HTML/CSS
# 83438           Java
# 83438     JavaScript
# Name: LanguageHaveWorkedWith, Length: 443642, dtype: object

# %%
df['LanguageHaveWorkedWith']
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 83434    False
# 83435    False
# 83436    False
# 83437    False
# 83438    False
# Name: LanguageHaveWorkedWith, Length: 83439, dtype: bool

# %%
size_by_languages.nlargest(10).plot.pie(figsize=(10, 10))
size_by_languages.nlargest(10).plot.pie(figsize=(10, 10), autopct='%1.1f%%')

# %%
item_count = df['item_name'].value_counts()[:10]
for idx, (val, cnt) in enumerate(item_count.items(), 1):
    print("Top", idx, ":", val, cnt)

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

item_name_list = item_quantity.index.tolist()
x_pos = np.arange(len(item_name_list))
order_cnt = item_quantity.values.tolist()
 
plt.bar(x_pos, order_cnt, align='center')
plt.ylabel('ordered_item_count')
plt.title('Distribution of all orderd item')
 
plt.show()

# %%
df['item_price'] = df['item_price'].apply(lambda x: float(x[1:]))
df.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\sqlite\mysql\code\11_1\survey_results_public.ipynb 셀 27 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/sqlite/mysql/code/11_1/survey_results_public.ipynb#X35sZmlsZQ%3D%3D?line=0'>1</a> df['item_price'] = df['item_price'].apply(lambda x: float(x[1:]))
#       <a href='vscode-notebook-cell:/c%3A/sqlite/mysql/code/11_1/survey_results_public.ipynb#X35sZmlsZQ%3D%3D?line=1'>2</a> df.describe()
#
# NameError: name 'df' is not defined

# %%
chipo_orderid_group = df.groupby('order_id').sum() # ORDER ID를 기준으로 인원을 세서 GROUP에 할당
results = chipo_orderid_group[chipo_orderid_group.item_price >= 10] # 그룹화한것에서 item_price가 10 이상인것
