# %%
import pandas as pd

filename = r'C:\\sqlite\\mysql\\code\\AI\\Mid_project\\data\\(경기_전처리_완)어린이보호구역표시(17-22).csv'

df = pd.read_csv(filename)
df
# Out:
#                   사고번호               사고일시   요일               시군구    사고내용  \
# 0     2020010100100140    2020년 1월 1일 11시  수요일  경기도 안산시 단원구 대부북동    경상사고
# 1     2020010100100203    2020년 1월 1일 15시  수요일   경기도 안산시 단원구 신길동    경상사고
# 2     2020010100100255    2020년 1월 1일 17시  수요일      경기도 의정부시 녹양동    중상사고
# 3     2020010100100265    2020년 1월 1일 18시  수요일       경기도 이천시 신둔면    중상사고
# 4     2020010100100353    2020년 1월 1일 22시  수요일      경기도 남양주시 별내동    경상사고
# ...                ...                ...  ...               ...     ...
# 7521  2022123000100514  2022년 12월 30일 18시  금요일   경기도 수원시 영통구 이의동    경상사고
# 7522  2022123000100570  2022년 12월 30일 19시  금요일       경기도 의왕시 월암동    경상사고
# 7523  2022123000100585  2022년 12월 30일 19시  금요일       경기도 파주시 당하동    중상사고
# 7524  2022123000100599  2022년 12월 30일 20시  금요일       경기도 안성시 대덕면  부상신고사고
# 7525  2022123100100337  2022년 12월 31일 16시  토요일   경기도 고양시 덕양구 도내동    중상사고
#
#       사망자수  중상자수  경상자수  부상신고자수         사고유형  ... 기상상태             도로형태  \
# ...

# %%
df = df[df['피해운전자 연령'] <= '12세']

# %%
df
# Out:
#                   사고번호               사고일시   요일              시군구    사고내용  사망자수  \
# 8     2020010200100276    2020년 1월 2일 15시  목요일      경기도 안성시 석정동    경상사고     0
# 29    2020010500100156    2020년 1월 5일 12시  일요일  경기도 용인시 기흥구 청덕동  부상신고사고     0
# 38    2020010600100091    2020년 1월 6일 08시  월요일      경기도 부천시 춘의동    경상사고     0
# 49    2020010700100340    2020년 1월 7일 15시  화요일      경기도 시흥시 은행동    중상사고     0
# 59    2020010800100401    2020년 1월 8일 17시  수요일  경기도 안산시 단원구 선부동    중상사고     0
# ...                ...                ...  ...              ...     ...   ...
# 7465  2022122400100132  2022년 12월 24일 11시  토요일  경기도 성남시 수정구 수진동    경상사고     0
# 7482  2022122500100230  2022년 12월 25일 16시  일요일      경기도 평택시 장안동  부상신고사고     0
# 7491  2022122700100340  2022년 12월 27일 15시  화요일      경기도 포천시 소흘읍    중상사고     0
# 7506  2022122900100255  2022년 12월 29일 13시  목요일     경기도 동두천시 지행동    경상사고     0
# 7510  2022122900100417  2022년 12월 29일 17시  목요일       경기도 가평군 북면    중상사고     0
#
# ...

# %%
filename_2 = 'C:\\sqlite\\mysql\\code\\AI\\Mid_project\\num-data\\경기-어린이보호구역사고20-22.csv'

df_2 = pd.read_csv(filename_2)
df_2
# Out:
#                  사고번호               사고일시   요일                시군구  사고내용  사망자수  \
# 0    2020010300100617    2020년 1월 3일 23시  금요일  경기도 고양시 일산동구 정발산동  경상사고     0
# 1    2020010800100407    2020년 1월 8일 17시  수요일    경기도 용인시 수지구 죽전동  중상사고     0
# 2    2020011000100510   2020년 1월 10일 19시  금요일    경기도 용인시 처인구 고림동  경상사고     0
# 3    2020011100100256   2020년 1월 11일 13시  토요일        경기도 김포시 풍무동  중상사고     0
# 4    2020011500100200   2020년 1월 15일 11시  수요일        경기도 양주시 광적면  경상사고     0
# ..                ...                ...  ...                ...   ...   ...
# 994  2022122700100458  2022년 12월 27일 18시  화요일       경기도 의정부시 민락동  중상사고     0
# 995  2022122800100285  2022년 12월 28일 14시  수요일        경기도 화성시 우정읍  경상사고     0
# 996  2022122800100306  2022년 12월 28일 14시  수요일       경기도 남양주시 호평동  경상사고     0
# 997  2022122900100396  2022년 12월 29일 17시  목요일        경기도 화성시 장지동  중상사고     0
# 998  2022123100100319  2022년 12월 31일 16시  토요일        경기도 오산시 고현동  경상사고     0
#
# ...

# %%
df_2 = df_2[df_2['피해운전자 연령'] <= '12세']

# %%
df_2
# Out:
#                  사고번호               사고일시   요일              시군구    사고내용  사망자수  \
# 1    2020010800100407    2020년 1월 8일 17시  수요일  경기도 용인시 수지구 죽전동    중상사고     0
# 5    2020011500100395   2020년 1월 15일 17시  수요일      경기도 군포시 금정동    경상사고     0
# 17   2020020800100306    2020년 2월 8일 15시  토요일  경기도 성남시 수정구 태평동    경상사고     0
# 25   2020021800100683   2020년 2월 18일 20시  화요일      경기도 파주시 목동동    중상사고     0
# 48   2020032700100440   2020년 3월 27일 18시  금요일      경기도 포천시 소흘읍    중상사고     0
# ..                ...                ...  ...              ...     ...   ...
# 961  2022111600100648  2022년 11월 16일 20시  수요일     경기도 의정부시 용현동    경상사고     0
# 970  2022112500100339  2022년 11월 25일 16시  금요일  경기도 안양시 동안구 평촌동  부상신고사고     0
# 971  2022112600100233  2022년 11월 26일 13시  토요일      경기도 부천시 원종동    경상사고     0
# 978  2022120500100217   2022년 12월 5일 14시  월요일  경기도 성남시 수정구 태평동    중상사고     0
# 990  2022121900100489  2022년 12월 19일 19시  월요일      경기도 구리시 교문동  부상신고사고     0
#
# ...

# %%
merge_df = pd.merge(df, df_2, how='outer', indicator=True)\
    .query("_merge=='left_only'")\
    .drop(columns=['_merge'])

# %%
merge_df.to_excel('C:\\sqlite\\mysql\\code\\AI\\Mid_project\\num-data\\보호구역외사고.xlsx')

# %%
merge_df = merge_df.astype({'사고일시':'string'})

# %%
merge_df['사고일시'] = merge_df['사고일시'].replace({'년':'', '월':'', '일':'', '시':''}, regex=True)

# %%
merge_df_split = merge_df['사고일시'].str.split(' ', expand=True)

# %%
merge_df['발생시간'] = merge_df_split[3]

# %%
merge_df['사고일시'] = merge_df_split[0]+merge_df_split[1]+merge_df_split[2]

# %%
merge_df['발생시간'].astype({'발생시간':'int64'})
# Out:
# 0       15
# 1       12
# 2        8
# 3       15
# 4       17
#         ..
# 1006    11
# 1007    16
# 1008    15
# 1009    13
# 1010    17
# Name: 발생시간, Length: 877, dtype: int64

# %%
merge_df['사고일시']
# Out:
# 0         202012
# 1         202015
# 2         202016
# 3         202017
# 4         202018
#           ...
# 1006    20221224
# 1007    20221225
# 1008    20221227
# 1009    20221229
# 1010    20221229
# Name: 사고일시, Length: 877, dtype: string

# %%
merge_df['발생년월일시'] = pd.to_datetime(merge_df['사고일시'], format='%Y%m%d')

# %%
merge_df
# Out:
#                   사고번호      사고일시   요일              시군구    사고내용  사망자수  중상자수  \
# 0     2020010200100276    202012  목요일      경기도 안성시 석정동    경상사고     0     0
# 1     2020010500100156    202015  일요일  경기도 용인시 기흥구 청덕동  부상신고사고     0     0
# 2     2020010600100091    202016  월요일      경기도 부천시 춘의동    경상사고     0     0
# 3     2020010700100340    202017  화요일      경기도 시흥시 은행동    중상사고     0     1
# 4     2020010800100401    202018  수요일  경기도 안산시 단원구 선부동    중상사고     0     1
# ...                ...       ...  ...              ...     ...   ...   ...
# 1006  2022122400100132  20221224  토요일  경기도 성남시 수정구 수진동    경상사고     0     0
# 1007  2022122500100230  20221225  일요일      경기도 평택시 장안동  부상신고사고     0     0
# 1008  2022122700100340  20221227  화요일      경기도 포천시 소흘읍    중상사고     0     1
# 1009  2022122900100255  20221229  목요일     경기도 동두천시 지행동    경상사고     0     0
# 1010  2022122900100417  20221229  목요일       경기도 가평군 북면    중상사고     0     1
#
# ...

# %%
import plotly.express as px
fig = px.bar(merge_df, x='요일',y='피해운전자 연령',color='피해운전자 성별', height=1000, width=1000)
fig.show()

# %%
merge_df['total'] = merge_df[['사망자수','중상자수','경상자수']].sum(axis=1)

# %%
merge_df
# Out:
#                   사고번호      사고일시   요일              시군구    사고내용  사망자수  중상자수  \
# 0     2020010200100276    202012  목요일      경기도 안성시 석정동    경상사고     0     0
# 1     2020010500100156    202015  일요일  경기도 용인시 기흥구 청덕동  부상신고사고     0     0
# 2     2020010600100091    202016  월요일      경기도 부천시 춘의동    경상사고     0     0
# 3     2020010700100340    202017  화요일      경기도 시흥시 은행동    중상사고     0     1
# 4     2020010800100401    202018  수요일  경기도 안산시 단원구 선부동    중상사고     0     1
# ...                ...       ...  ...              ...     ...   ...   ...
# 1006  2022122400100132  20221224  토요일  경기도 성남시 수정구 수진동    경상사고     0     0
# 1007  2022122500100230  20221225  일요일      경기도 평택시 장안동  부상신고사고     0     0
# 1008  2022122700100340  20221227  화요일      경기도 포천시 소흘읍    중상사고     0     1
# 1009  2022122900100255  20221229  목요일     경기도 동두천시 지행동    경상사고     0     0
# 1010  2022122900100417  20221229  목요일       경기도 가평군 북면    중상사고     0     1
#
# ...

# %%
merge_df_set = merge_df[['사망자수', '중상자수','경상자수' ,'사고일시']]

# %%
merge_df_set['사고일시'] = pd.to_datetime(merge_df_set['사고일시'], format='%Y%m%d')
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_12016\2015047612.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
merge_df_set['년월'] = merge_df_set['사고일시'].dt.to_period('M')
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_12016\593221370.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
columns_to_sum = ['사망자수', '중상자수', '경상자수']

# '년월' 컬럼으로 그룹화하고 지정한 컬럼의 합계 계산
monthly_sum = merge_df_set.groupby('년월')[columns_to_sum].sum().reset_index()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(17, 7))
sns.lineplot(data=monthly_sum, palette='colorblind', linewidth=2)
plt.rc('font', family='Malgun Gothic')

plt.title('보호구역외사고 20-22', fontsize=20)
plt.xlabel('날짜', fontsize=15)
plt.xticks(rotation = 30)
plt.ylabel('피해자', fontsize=15)
# Out:
# Text(0, 0.5, '피해자')

# %%
filename_3 = r'C:\\sqlite\\mysql\\code\\AI\\Mid_project\\data\\보호구역외사고_좌표.xlsx'
import folium
wb = pd.read_excel(filename_3)
wb.columns = ['주소','x','y']

# print(df_from_excel)
name_list = wb.iloc[:, 0].tolist()
px_list = wb.iloc[:, 1].tolist()
py_list = wb.iloc[:, 2].tolist()
map = folium.Map(location=[37, 127], zoom_start=7)

for i in range(len(name_list)):
    if px_list[i]!= 0:
        print(px_list[i], py_list[i])
        marker = folium.Marker([py_list[i], px_list[i]], popup=name_list[i], icon=folium.Icon(color='red'))
        marker.add_to(map)

map.show_in_browser()

# %%
# fig = px.choropleth_mapbox(df, geojson=state_geo1, 
#                            locations='sigun_code', 
#                            color='소멸위험지수',
#                            color_continuous_scale="matter",
#                            range_color=(0, 2),
#                            mapbox_style="carto-positron",
#                            featureidkey="properties.merged",                           
#                            zoom=6, center = {"lat": 37.565, "lon": 126.986},
#                            opacity=0.5,
#                            labels={'소멸위험지수':'지자체별 소멸위험지수'}
#                           )
# fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
# fig.show()
