# %%
import pandas as pd

filename = 'C:\\sqlite\\mysql\\code\\AI\\Mid_project\\data\\사고유형별(스쿨존).xls'

df = pd.read_excel(filename)
df
# Out:
#           기준년도  2022 2022.1      2022.2 2022.3 2022.4 2022.5 2022.6 2022.7  \
# 0         기준년도  차대사람   차대사람        차대사람   차대사람   차대사람    차대차    차대차    차대차
# 1         기준년도   횡단중  차도통행중  길가장자리구역통행중  보도통행중     기타   정면충돌   측면충돌     추돌
# 2         기준년도   횡단중  차도통행중  길가장자리구역통행중  보도통행중     기타   정면충돌   측면충돌     추돌
# 3        사고[건]   245     27           8     18     83      9     72      6
# 4        사망[명]     0      0           0      0      3      0      0      0
# 5        부상[명]   250     27           8     18     83     10     77      7
# 6  출처) 도로교통공단.   NaN    NaN         NaN    NaN    NaN    NaN    NaN    NaN
#
#   2022.8 2022.9
# 0    차대차   차량단독
# 1     기타  공작물충돌
# 2     기타  공작물충돌
# 3     45      1
# 4      0      0
# 5     48      1
# 6    NaN    NaN

# %%
df = df.dropna()
df
# Out:
#     기준년도  2022 2022.1      2022.2 2022.3 2022.4 2022.5 2022.6 2022.7 2022.8  \
# 0   기준년도  차대사람   차대사람        차대사람   차대사람   차대사람    차대차    차대차    차대차    차대차
# 1   기준년도   횡단중  차도통행중  길가장자리구역통행중  보도통행중     기타   정면충돌   측면충돌     추돌     기타
# 2   기준년도   횡단중  차도통행중  길가장자리구역통행중  보도통행중     기타   정면충돌   측면충돌     추돌     기타
# 3  사고[건]   245     27           8     18     83      9     72      6     45
# 4  사망[명]     0      0           0      0      3      0      0      0      0
# 5  부상[명]   250     27           8     18     83     10     77      7     48
#
#   2022.9
# 0   차량단독
# 1  공작물충돌
# 2  공작물충돌
# 3      1
# 4      0
# 5      1

# %%
df.drop([1], inplace=True)
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_25124\1771959160.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop([1], inplace=True)

# %%
df = df.rename(index={0:'사고별',2:'사고유형',3:'사고[건]',4:'사망[명]',5:'부상[명]'})
df
# Out:
#         기준년도  2022 2022.1      2022.2 2022.3 2022.4 2022.5 2022.6 2022.7  \
# 사고별     기준년도  차대사람   차대사람        차대사람   차대사람   차대사람    차대차    차대차    차대차
# 사고유형    기준년도   횡단중  차도통행중  길가장자리구역통행중  보도통행중     기타   정면충돌   측면충돌     추돌
# 사고[건]  사고[건]   245     27           8     18     83      9     72      6
# 사망[명]  사망[명]     0      0           0      0      3      0      0      0
# 부상[명]  부상[명]   250     27           8     18     83     10     77      7
#
#       2022.8 2022.9
# 사고별      차대차   차량단독
# 사고유형      기타  공작물충돌
# 사고[건]     45      1
# 사망[명]      0      0
# 부상[명]     48      1

# %%
df.drop(['기준년도'], axis=1,inplace=True)
df
# Out:
#        2022 2022.1      2022.2 2022.3 2022.4 2022.5 2022.6 2022.7 2022.8  \
# 사고별    차대사람   차대사람        차대사람   차대사람   차대사람    차대차    차대차    차대차    차대차
# 사고유형    횡단중  차도통행중  길가장자리구역통행중  보도통행중     기타   정면충돌   측면충돌     추돌     기타
# 사고[건]   245     27           8     18     83      9     72      6     45
# 사망[명]     0      0           0      0      3      0      0      0      0
# 부상[명]   250     27           8     18     83     10     77      7     48
#
#       2022.9
# 사고별     차량단독
# 사고유형   공작물충돌
# 사고[건]      1
# 사망[명]      0
# 부상[명]      1

# %%
df = df.transpose()

# %%
df.drop(['2022.1','2022.2','2022.3','2022.4','2022.5','2022.6','2022.7','2022.8','2022.9'], inplace=True)

# %%
df
# Out:
#        사고별 사고유형 사고[건] 사망[명] 부상[명]
# 2022  차대사람  횡단중   245     0   250

# %%
from matplotlib import pyplot as plt
from matplotlib import font_manager, rc
df.plot(kind='bar')
font_name = font_manager.FontProperties(fname="C:\\Windows\\Fonts\\malgun.ttf").get_name()
rc('font', family=font_name)
