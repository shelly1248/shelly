# %%
# import pandas as pd
# import geopandas as gpd
# import folium
# from shapely.geometry import Point
# from folium.plugins import MarkerCluster

# # 데이터 로드
# df = pd.read_excel('C:\\sqlite\\mysql\\code\\AI\\Mid_project\\data\\file\\all_test - 복사본.xlsx')

# # '피해운전자 상해정도'에 따라 데이터를 그룹화하고 카운트
# grouped_df = df.groupby(['시군구', '피해운전자 상해정도']).size().reset_index(name='상해정도 갯수')


# # '시군구'별로 '피해운전자 상해정도'와 '상해정도 갯수'를 문자열로 변환
# grouped_df['피해운전자 상해정도'] = grouped_df['피해운전자 상해정도'].astype(str)
# grouped_df['상해정도 갯수'] = grouped_df['상해정도 갯수'].astype(str)
# grouped_df['상해정도 정보'] = grouped_df[['피해운전자 상해정도', '상해정도 갯수']].apply(lambda x: ': '.join(x), axis=1)

# # '시군구'별로 '상해정도 정보'를 모음
# grouped_df_agg = grouped_df.groupby('시군구')['상해정도 정보'].apply(lambda x: '<br>'.join(x)).reset_index()

# # 시군구별로 그룹화하여 첫번째 데이터를 가져옴
# df_all = pd.read_excel('C:\\sqlite\\mysql\\code\\AI\\total좌표.xlsx')
# columns = ["시군구", "경도", "위도"]
# df_all.columns = columns
# first_all = df_all.groupby('시군구').first().reset_index()

# # 두 데이터프레임 병합
# first_all_merged = first_all.merge(grouped_df_agg, on='시군구', how='left')

# # 지리 데이터 생성
# geometry = [Point(lon, lat) for lat, lon in zip(first_all_merged['위도'], first_all_merged['경도'])]
# gdf_coordinates = gpd.GeoDataFrame(first_all_merged, geometry=geometry, crs='EPSG:4326')
# gdf_coordinates = gdf_coordinates[~gdf_coordinates['geometry'].is_empty]

# # 지도 생성
# mymap = folium.Map(location=(37,127), zoom_start=12, control_scale=True)
# marker_cluster = MarkerCluster().add_to(mymap)

# # 마커 추가
# for index, row in gdf_coordinates.iterrows():
#     if not row['geometry'].is_empty:
#         latitude = row['geometry'].y
#         longitude = row['geometry'].x
#         icon = folium.Icon(color='red', icon='info-sign')
#         popup_text = row['상해정도 정보']
#         folium.Marker(location=[latitude, longitude], icon=icon, popup=folium.Popup(popup_text, max_width=250)).add_to(marker_cluster)



# # 지도 저장
# mymap.save('C:\\sqlite\\mysql\\code\\AI\\Mid_project\\data\\file\\cartoon_map_with_injury_counts_test.html')

# %% [markdown]
# # 밑에 최종본

# %%
# import pandas as pd
# import geopandas as gpd
# import folium
# from shapely.geometry import Point
# from folium.plugins import MarkerCluster

# df = pd.read_excel('C:\\sqlite\\mysql\\code\\AI\\Mid_project\\data\\file\\all_test - 복사본.xlsx')

# grouped_df = df.groupby(['시군구', '피해운전자 상해정도']).size().reset_index(name='상해정도 갯수')

# grouped_df['피해운전자 상해정도'] = grouped_df['피해운전자 상해정도'].astype(str)
# grouped_df['상해정도 갯수'] = grouped_df['상해정도 갯수'].astype(str)
# grouped_df['상해정도 정보'] = grouped_df[['피해운전자 상해정도', '상해정도 갯수']].apply(lambda x: ': '.join(x), axis=1)

# grouped_df_agg = grouped_df.groupby('시군구')['상해정도 정보'].apply(lambda x: '<br>'.join(x)).reset_index()

# df_all = pd.read_excel('C:\\sqlite\\mysql\\code\\AI\\total좌표.xlsx')
# columns = ["시군구", "경도", "위도"]
# df_all.columns = columns
# first_all = df_all.groupby('시군구').first().reset_index()

# first_all_merged = first_all.merge(grouped_df_agg, on='시군구', how='left')

# geometry = [Point(lon, lat) for lat, lon in zip(first_all_merged['위도'], first_all_merged['경도'])]
# gdf_coordinates = gpd.GeoDataFrame(first_all_merged, geometry=geometry, crs='EPSG:4326')
# gdf_coordinates = gdf_coordinates[~gdf_coordinates['geometry'].is_empty]

# mymap = folium.Map(location=(37,127), zoom_start=12, control_scale=True)
# marker_cluster = MarkerCluster().add_to(mymap)

# for index, row in gdf_coordinates.iterrows():
#     if not row['geometry'].is_empty:
#         latitude = row['geometry'].y
#         longitude = row['geometry'].x
#         icon = folium.Icon(color='red', icon='info-sign')
#         popup_text = row['상해정도 정보']
#         folium.Marker(location=[latitude, longitude], icon=icon, popup=folium.Popup(popup_text, max_width=250)).add_to(marker_cluster)

# first_all_merged['상해정도 갯수'] = grouped_df['상해정도 갯수']


# first_all_merged['상해정도 갯수'] = first_all_merged['상해정도 갯수'].astype(int)

# for index, row in first_all_merged.iterrows():
#     latitude = row['위도']
#     longitude = row['경도']
#     injury_count = row['상해정도 갯수'] 

#     radius = 50 

#     folium.CircleMarker(
#         location=[latitude, longitude],
#         radius=radius,
#         color='blue',
#         fill=True,
#         fill_color='blue',
#         fill_opacity=0.2
#     ).add_to(mymap)

# mymap.save('C:\\sqlite\\mysql\\code\\AI\\Mid_project\\data\\file\\cartoon_map_with_injury_counts_test.html')

# %%
# import geopandas as gpd
# import folium
# from folium.plugins import HeatMap
# from shapely.geometry import Point
# from branca.colormap import LinearColormap

# df['시/구total'] = df.groupby('시/구')['피해운전자 상해정도'].transform('count')

# geometry = [Point(lon, lat) for lat, lon in zip(df['위도'], df['경도'])]
# gdf_coordinates = gpd.GeoDataFrame(df, geometry=geometry, crs='EPSG:4326')

# gdf_coordinates = gdf_coordinates[~gdf_coordinates['geometry'].is_empty]

# total = gdf_coordinates.groupby('geometry')['피해운전자 상해정도'].count().reset_index(name='total')
# gdf_coordinates = gdf_coordinates.merge(total, on='geometry')

# map_center = [gdf_coordinates['위도'].mean(), gdf_coordinates['경도'].mean()]
# mymap = folium.Map(location=map_center, zoom_start=12, control_scale=True)

# heat_data = []
# for index, row in gdf_coordinates.iterrows():
#     if not row['geometry'].is_empty:
#         latitude = row['geometry'].y
#         longitude = row['geometry'].x
#         total_count = row['시/구total']
#         heat_data.append([latitude, longitude, total_count])

# colors = ['#cce5ff', '#99c2ff', '#66a3ff', '#3385ff', '#0055ff']

# colormap = LinearColormap(colors=colors, index=[0, 0.2, 0.4, 0.6, 0.8, 1], vmin=gdf_coordinates['시/구total'].min(), vmax=gdf_coordinates['시/구total'].max(), caption='Total Counts')

# colormap.add_to(mymap)

# HeatMap(heat_data, min_opacity=0.6, max_val=gdf_coordinates['시/구total'].max(), radius=15, blur=10, max_zoom=1).add_to(mymap)

# mymap.save('C:\\sqlite\\mysql\\code\\AI\\Mid_project\\data\\file\\map_with_injury_counts.html')

# %%
# import pandas as pd
# import geopandas as gpd
# import folium
# from shapely.geometry import Point
# from folium.plugins import MarkerCluster

# df = pd.read_excel('C:\\sqlite\\mysql\\code\\AI\\Mid_project\\data\\file\\all_test - 복사본.xlsx')

# grouped_df = df.groupby(['시군구', '피해운전자 상해정도']).size().reset_index(name='상해정도 갯수')

# grouped_df['피해운전자 상해정도'] = grouped_df['피해운전자 상해정도'].astype(str)
# grouped_df['상해정도 갯수'] = grouped_df['상해정도 갯수'].astype(str)
# grouped_df['상해정도 정보'] = grouped_df[['피해운전자 상해정도', '상해정도 갯수']].apply(lambda x: ': '.join(x), axis=1)

# grouped_df_agg = grouped_df.groupby('시군구')['상해정도 정보'].apply(lambda x: '<br>'.join(x)).reset_index()

# df_all = pd.read_excel('C:\\sqlite\\mysql\\code\\AI\\total좌표.xlsx')
# columns = ["시군구", "경도", "위도"]
# df_all.columns = columns
# first_all = df_all.groupby('시군구').first().reset_index()

# first_all_merged = first_all.merge(grouped_df_agg, on='시군구', how='left')

# geometry = [Point(lon, lat) for lat, lon in zip(first_all_merged['위도'], first_all_merged['경도'])]
# gdf_coordinates = gpd.GeoDataFrame(first_all_merged, geometry=geometry, crs='EPSG:4326')
# gdf_coordinates = gdf_coordinates[~gdf_coordinates['geometry'].is_empty]

# mymap = folium.Map(location=(37.53,127), zoom_start=10, control_scale=True)
# marker_cluster = MarkerCluster().add_to(mymap)

# for index, row in gdf_coordinates.iterrows():
#     if not row['geometry'].is_empty:
#         latitude = row['geometry'].y
#         longitude = row['geometry'].x
#         icon = folium.Icon(color='red', icon='info-sign')
#         popup_text = row['상해정도 정보']
#         folium.Marker(location=[latitude, longitude], icon=icon, popup=folium.Popup(popup_text, max_width=250)).add_to(marker_cluster)

# first_all_merged['상해정도 갯수'] = grouped_df['상해정도 갯수']


# first_all_merged['상해정도 갯수'] = first_all_merged['상해정도 갯수'].astype(int)

# for index, row in first_all_merged.iterrows():
#     latitude = row['위도']
#     longitude = row['경도']
#     injury_count = row['상해정도 갯수'] 

#     radius = 50 

#     folium.CircleMarker(
#         location=[latitude, longitude],
#         radius=radius,
#         color='yellow',
#         fill=True,
#         fill_color='yellow',
#         fill_opacity=0.1
#     ).add_to(mymap)

# for index, row in first_all_merged.iterrows():

#     radius = 50 

#     folium.CircleMarker(
#         location=[latitude, longitude],
#         radius=radius,
#         color='red',
#         fill=True,
#         fill_color='red',
#         fill_opacity=0.1
#     ).add_to(mymap)


# gdf_protect = gpd.read_file('C:\\sqlite\\mysql\\code\\AI\\gyeonggi_protect_polygons.geojson')
# folium.GeoJson(
#     gdf_protect,
#     name='protection zones',
#     style_function=lambda x: {'fillColor': '#FF0000', 'fillOpacity': 0.5}
# ).add_to(mymap)



# mymap.save('C:\\sqlite\\mysql\\code\\AI\\Mid_project\\data\\file\\cartoon_map_with_injury_counts_test.html')

# %%
# import geopandas as gpd
# from shapely.geometry import Polygon
# import json
# import re


# path = r'C:\\sqlite\\mysql\\code\\AI\\Mid_project\\data\\file\\'

# with open(path + '전국어린이보호구역표준데이터.json', 'r', encoding='UTF8') as j:
#     contents = json.load(j)

# records = contents['records']

# polygon_list = []

# for record in records:
#     lon = float(record['경도'])
#     lat = float(record['위도'])
#     coords = [(lon+0.003, lat+0.003), (lon+0.003, lat-0.003),
#               (lon-0.003, lat-0.003), (lon-0.003, lat+0.003)]
#     polygon = Polygon(coords)
#     polygon_list.append(polygon)

# geo_df = gpd.GeoDataFrame(records, geometry=polygon_list)

# def get_province(name):
#     match = re.match(r'^(서울특별시|부산광역시|대구광역시|인천광역시|광주광역시|대전광역시|울산광역시|세종특별자치시|경기도|강원도|충청북도|충청남도|전라북도|전라남도|경상북도|경상남도|제주특별자치도)', name)
#     if match:
#         return match.group(1)
#     return None

# # geo_df['도'] = geo_df['제공기관명'].str.split(' ').str[0]
# geo_df['도'] = geo_df['제공기관명'].apply(get_province)

# geo_df = geo_df[(geo_df['도'] == '경기도') | (geo_df['도'] == '서울특별시')]

# geo_df.to_file('C:\\sqlite\\mysql\\code\\AI\\gyeonggi_protect_polygons_test.geojson', driver='GeoJSON')

# %% [markdown]
# # 보호구역 테두리 제거

# %%
# import pandas as pd
# import geopandas as gpd
# import folium
# from shapely.geometry import Point
# from folium.plugins import MarkerCluster

# df = pd.read_excel('C:\\sqlite\\mysql\\code\\AI\\Mid_project\\data\\file\\all_test - 복사본.xlsx')

# grouped_df = df.groupby(['시군구', '피해운전자 상해정도']).size().reset_index(name='상해정도 갯수')

# grouped_df['피해운전자 상해정도'] = grouped_df['피해운전자 상해정도'].astype(str)
# grouped_df['상해정도 갯수'] = grouped_df['상해정도 갯수'].astype(str)
# grouped_df['상해정도 정보'] = grouped_df[['피해운전자 상해정도', '상해정도 갯수']].apply(lambda x: ': '.join(x), axis=1)

# grouped_df_agg = grouped_df.groupby('시군구')['상해정도 정보'].apply(lambda x: '<br>'.join(x)).reset_index()

# df_all = pd.read_excel('C:\\sqlite\\mysql\\code\\AI\\total좌표.xlsx')
# columns = ["시군구", "경도", "위도"]
# df_all.columns = columns
# first_all = df_all.groupby('시군구').first().reset_index()

# first_all_merged = first_all.merge(grouped_df_agg, on='시군구', how='left')

# geometry = [Point(lon, lat) for lat, lon in zip(first_all_merged['위도'], first_all_merged['경도'])]
# gdf_coordinates = gpd.GeoDataFrame(first_all_merged, geometry=geometry, crs='EPSG:4326')
# gdf_coordinates = gdf_coordinates[~gdf_coordinates['geometry'].is_empty]

# mymap = folium.Map(location=(37.53,127), zoom_start=10, control_scale=True)
# marker_cluster = MarkerCluster().add_to(mymap)

# for index, row in gdf_coordinates.iterrows():
#     if not row['geometry'].is_empty:
#         latitude = row['geometry'].y
#         longitude = row['geometry'].x
#         icon = folium.Icon(color='red', icon='info-sign')
#         popup_text = row['상해정도 정보']
#         folium.Marker(location=[latitude, longitude], icon=icon, popup=folium.Popup(popup_text, max_width=250)).add_to(marker_cluster)


# first_all_merged['상해정도 갯수'] = grouped_df['상해정도 갯수']

# first_all_merged['상해정도 갯수'] = first_all_merged['상해정도 갯수'].astype(int)


# for index, row in first_all_merged.iterrows():
#     latitude = row['위도']
#     longitude = row['경도']
#     injury_count = row['상해정도 갯수'] 

#     radius = 50 

#     folium.CircleMarker(
#         location=[latitude, longitude],
#         radius=radius,
#         color='yellow',
#         fill=True,
#         fill_color='yellow',
#         fill_opacity=0.1
#     ).add_to(mymap)

# grouped_df = first_all_merged.groupby('시군구')['상해정도 갯수'].sum().reset_index()
# first_all_merged = pd.merge(first_all_merged, grouped_df, on='시군구', how='left')

# for index, row in first_all_merged.iterrows():

#     latitude = row['위도']
#     longitude = row['경도']
#     total_injury_count = row['상해정도 갯수_y']
#     radius = total_injury_count 
#     folium.CircleMarker(
#         location=[latitude, longitude],
#         radius=radius,
#         color='red',
#         fill=True,
#         fill_color='red',
#         fill_opacity=0.1
#     ).add_to(mymap)



# gdf_protect = gpd.read_file('C:\\sqlite\\mysql\\code\\AI\\gyeonggi_protect_polygons_test.geojson')
# folium.GeoJson(
#     'C:\\sqlite\\mysql\\code\\AI\\gyeonggi_protect_polygons_test.geojson',
#     style_function=lambda feature: {
#         'fillColor': '#ffff00',
#         'color': 'transparent',  # 테두리 색상을 투명하게 설정
#         'weight': 0,  # 테두리 두께를 0으로 설정
#         'fillOpacity': '0.5',
#     }
# ).add_to(mymap)
# # folium.GeoJson(
# #     gdf_protect,
# #     name='protection zones',
# #     style_function=lambda x: {'fillColor': '#FF0000', 'fillOpacity': 0.5}
# # ).add_to(mymap)



# mymap.save('C:\\sqlite\\mysql\\code\\AI\\Mid_project\\data\\file\\cartoon_map_with_injury_counts_test_1_1안.html')

# %%
# first_all_merged.to_csv('C:\\sqlite\\mysql\\code\\AI\\Mid_project\\data\\file\\merged_dataframe.csv', encoding='utf-8-sig', index=False)

# %% [markdown]
# # 도로 시각화 추가

# %%
# import pandas as pd
# import geopandas as gpd
# import folium
# from shapely.geometry import Point
# from folium.plugins import MarkerCluster

# df = pd.read_excel('C:\\sqlite\\mysql\\code\\AI\\Mid_project\\data\\file\\all_test - 복사본.xlsx')

# grouped_df = df.groupby(['시군구', '피해운전자 상해정도']).size().reset_index(name='상해정도 갯수')

# grouped_df['피해운전자 상해정도'] = grouped_df['피해운전자 상해정도'].astype(str)
# grouped_df['상해정도 갯수'] = grouped_df['상해정도 갯수'].astype(str)
# grouped_df['상해정도 정보'] = grouped_df[['피해운전자 상해정도', '상해정도 갯수']].apply(lambda x: ': '.join(x), axis=1)

# grouped_df_agg = grouped_df.groupby('시군구')['상해정도 정보'].apply(lambda x: '<br>'.join(x)).reset_index()

# df_all = pd.read_excel('C:\\sqlite\\mysql\\code\\AI\\total좌표.xlsx')
# columns = ["시군구", "경도", "위도"]
# df_all.columns = columns
# first_all = df_all.groupby('시군구').first().reset_index()

# first_all_merged = first_all.merge(grouped_df_agg, on='시군구', how='left')

# geometry = [Point(lon, lat) for lat, lon in zip(first_all_merged['위도'], first_all_merged['경도'])]
# gdf_coordinates = gpd.GeoDataFrame(first_all_merged, geometry=geometry, crs='EPSG:4326')
# gdf_coordinates = gdf_coordinates[~gdf_coordinates['geometry'].is_empty]

# mymap = folium.Map(location=(37.53,127), zoom_start=10, control_scale=True)
# marker_cluster = MarkerCluster().add_to(mymap)

# for index, row in gdf_coordinates.iterrows():
#     if not row['geometry'].is_empty:
#         latitude = row['geometry'].y
#         longitude = row['geometry'].x
#         icon = folium.Icon(color='red', icon='info-sign')
#         popup_text = row['상해정도 정보']
#         folium.Marker(location=[latitude, longitude], icon=icon, popup=folium.Popup(popup_text, max_width=250)).add_to(marker_cluster)


# first_all_merged['상해정도 갯수'] = grouped_df['상해정도 갯수']

# first_all_merged['상해정도 갯수'] = first_all_merged['상해정도 갯수'].astype(int)


# for index, row in first_all_merged.iterrows():
#     latitude = row['위도']
#     longitude = row['경도']
#     injury_count = row['상해정도 갯수'] 

#     radius = 50 

#     folium.CircleMarker(
#         location=[latitude, longitude],
#         radius=radius,
#         color='yellow',
#         fill=True,
#         fill_color='yellow',
#         fill_opacity=0.1
#     ).add_to(mymap)

# grouped_df = first_all_merged.groupby('시군구')['상해정도 갯수'].sum().reset_index()
# first_all_merged = pd.merge(first_all_merged, grouped_df, on='시군구', how='left')

# for index, row in first_all_merged.iterrows():

#     latitude = row['위도']
#     longitude = row['경도']
#     total_injury_count = row['상해정도 갯수_y']
#     radius = total_injury_count 
#     folium.CircleMarker(
#         location=[latitude, longitude],
#         radius=radius,
#         color='red',
#         fill=True,
#         fill_color='red',
#         fill_opacity=0.1
#     ).add_to(mymap)

# gdf_road = gpd.read_file('C:\\sqlite\\mysql\\code\\AI\\Mid_project\\data\\sig.shp')
# gdf_road = gdf_road.set_crs(epsg=5179)
# gdf_road['region_code'] = gdf_road['SIG_CD'].str[:2]
# gdf_road = gdf_road[gdf_road['region_code'].isin(['11', '41'])]
# # Folium 지도에 GeoJSON 추가
# folium.GeoJson(
#     gdf_road,
#     style_function=lambda feature: {
#         'fillColor': '#000000',  # 도로 색상을 검은색으로 설정
#         'color': '#000000',  # 도로 테두리 색상을 검은색으로 설정
#         'weight': 0.5,  # 도로 테두리 두께를 1로 설정
#         'fillOpacity': 0,  # 도로 채우기 불투명도를 1.0으로 설정
#     }
# ).add_to(mymap)



# gdf_protect = gpd.read_file('C:\\sqlite\\mysql\\code\\AI\\gyeonggi_protect_polygons_test.geojson')
# folium.GeoJson(
#     'C:\\sqlite\\mysql\\code\\AI\\gyeonggi_protect_polygons_test.geojson',
#     style_function=lambda feature: {
#         'fillColor': '#ffff00',
#         'color': 'transparent',  # 테두리 색상을 투명하게 설정
#         'weight': 0,  # 테두리 두께를 0으로 설정
#         'fillOpacity': 0.5,
#     }
# ).add_to(mymap)


# mymap.save('C:\\sqlite\\mysql\\code\\AI\\Mid_project\\data\\file\\cartoon_map_with_injury_counts_test_1_1안.html')

# %% [markdown]
# # 수정 중

# %%
# import pandas as pd
# import geopandas as gpd
# import folium
# from shapely.geometry import Point
# from folium.plugins import MarkerCluster
# from shapely.geometry import Point
# from shapely.ops import unary_union
# df = pd.read_excel('C:\\sqlite\\mysql\\code\\AI\\Mid_project\\data\\file\\all_test - 복사본.xlsx')

# grouped_df = df.groupby(['시군구', '피해운전자 상해정도']).size().reset_index(name='상해정도 갯수')

# grouped_df['피해운전자 상해정도'] = grouped_df['피해운전자 상해정도'].astype(str)
# grouped_df['상해정도 갯수'] = grouped_df['상해정도 갯수'].astype(str)
# grouped_df['상해정도 정보'] = grouped_df[['피해운전자 상해정도', '상해정도 갯수']].apply(lambda x: ': '.join(x), axis=1)

# grouped_df_agg = grouped_df.groupby('시군구')['상해정도 정보'].apply(lambda x: '<br>'.join(x)).reset_index()

# df_all = pd.read_excel('C:\\sqlite\\mysql\\code\\AI\\total좌표.xlsx')
# columns = ["시군구", "경도", "위도"]
# df_all.columns = columns
# first_all = df_all.groupby('시군구').first().reset_index()

# first_all_merged = first_all.merge(grouped_df_agg, on='시군구', how='left')

# geometry = [Point(lon, lat) for lat, lon in zip(first_all_merged['위도'], first_all_merged['경도'])]
# gdf_coordinates = gpd.GeoDataFrame(first_all_merged, geometry=geometry, crs='EPSG:4326')
# gdf_coordinates = gdf_coordinates[~gdf_coordinates['geometry'].is_empty]

# mymap = folium.Map(location=(37.53,127), zoom_start=10, control_scale=True)
# marker_cluster = MarkerCluster().add_to(mymap)

# for index, row in gdf_coordinates.iterrows():
#     if not row['geometry'].is_empty:
#         latitude = row['geometry'].y
#         longitude = row['geometry'].x
#         icon = folium.Icon(color='red', icon='info-sign')
#         popup_text = row['상해정도 정보']
#         folium.Marker(location=[latitude, longitude], icon=icon, popup=folium.Popup(popup_text, max_width=250)).add_to(marker_cluster)


# first_all_merged['상해정도 갯수'] = grouped_df['상해정도 갯수']

# first_all_merged['상해정도 갯수'] = first_all_merged['상해정도 갯수'].astype(int)


# for index, row in first_all_merged.iterrows():
#     latitude = row['위도']
#     longitude = row['경도']
#     injury_count = row['상해정도 갯수'] 

#     radius = 50 

#     folium.CircleMarker(
#         location=[latitude, longitude],
#         radius=radius,
#         color='yellow',
#         fill=True,
#         fill_color='yellow',
#         fill_opacity=0.1
#     ).add_to(mymap)

# grouped_df = first_all_merged.groupby('시군구')['상해정도 갯수'].sum().reset_index()
# first_all_merged = pd.merge(first_all_merged, grouped_df, on='시군구', how='left')

# for index, row in first_all_merged.iterrows():

#     latitude = row['위도']
#     longitude = row['경도']
#     total_injury_count = row['상해정도 갯수_y']
#     radius = total_injury_count 
#     folium.CircleMarker(
#         location=[latitude, longitude],
#         radius=radius,
#         color='red',
#         fill=True,
#         fill_color='red',
#         fill_opacity=0.1
#     ).add_to(mymap)

# gdf_road = gpd.read_file('C:\\sqlite\\mysql\\code\\AI\\Mid_project\\data\\sig.shp')
# gdf_road = gdf_road.set_crs(epsg=5179)
# gdf_road['region_code'] = gdf_road['SIG_CD'].str[:2]
# gdf_road = gdf_road[gdf_road['region_code'].isin(['11', '41'])]

# # Folium 지도에 GeoJSON 추가
# folium.GeoJson(
#     gdf_road,
#     style_function=lambda feature: {
#         'fillColor': '#000000',  # 도로 색상을 검은색으로 설정
#         'color': '#000000',  # 도로 테두리 색상을 검은색으로 설정
#         'weight': 0.5,  # 도로 테두리 두께를 1로 설정
#         'fillOpacity': 0,  # 도로 채우기 불투명도를 1.0으로 설정
#     }
# ).add_to(mymap)

# # Load the protect area data
# gdf_protect = gpd.read_file('C:\\sqlite\\mysql\\code\\AI\\gyeonggi_protect_polygons_test.geojson')

# # Convert polygons to circles
# def polygon_to_circle(polygon):
#     center = polygon.centroid
#     distance = center.distance(unary_union(polygon.boundary))
#     return center.buffer(distance)

# gdf_protect['geometry'] = gdf_protect['geometry'].apply(polygon_to_circle)

# # Add protect areas to the map
# folium.GeoJson(
#     gdf_protect,
#     style_function=lambda feature: {
#         'fillColor': '#ffff00',
#         'color': 'transparent',  # 테두리 색상을 투명하게 설정
#         'weight': 0,  # 테두리 두께를 0으로 설정
#         'fillOpacity': 0.5,
#     }
# ).add_to(mymap)


# mymap.save('C:\\sqlite\\mysql\\code\\AI\\Mid_project\\data\\file\\cartoon_map_with_injury_counts_test_1_1안.html')

# %% [markdown]
# # 중간완성본

# %%
import pandas as pd
import geopandas as gpd
import folium
from shapely.geometry import Point
from folium.plugins import MarkerCluster
from shapely.geometry import Point
from shapely.ops import unary_union
from branca.element import Template, MacroElement
import numpy as np
from folium import Element

df = pd.read_excel('C:\\sqlite\\mysql\\code\\AI\\Mid_project\\data\\file\\all_test - 복사본.xlsx')

# 지도 설명 HTML
template = """
{% macro html(this, kwargs) %}
<div style="
    position: fixed; 
    top: 5px;
    right: 5px;
    width: 270px;
    height: 220px;
    z-index:9999;
    font-size:14px;
    background: #f0f0f0;
    opacity: 0.9;
    padding: 5px;
    border-radius: 10px;
    ">
    <p><a style="color:#00ff00;font-size:150%;">&block;</a>&nbsp;: 위험도 낮음 (녹색)</p>
    <p><a style="color:#ff7f00;font-size:150%;">&block;</a>&nbsp;: 위험도 높음 (주황색)</p>
    <p><a style="color:#ff0000;font-size:150%;">&block;</a>&nbsp;: 위험도 매우 높음 (빨강색)</p>
    <p><img src='https://raw.githubusercontent.com/pointhi/leaflet-color-markers/master/img/marker-icon-2x-red.png' width='25' height='41'/>&nbsp;: 마커 (사고 발생 지역)</p>
    <p><a style="color:#0000ff;font-size:150%;">&#9679;</a>&nbsp;: 하늘색 구역 (어린이 보호 지역)</p>
</div>
<div style="
    position: fixed; 
    bottom: 5px;
    left: 5px;
    width: 250px;
    height: 40px;
    z-index:9999;
    font-size:14px;
    background: #f0f0f0;
    opacity: 0.9;
    padding: 5px;
    border-radius: 10px;
    ">
    <p><b>위험도: </b>위험도를 계산하여 색상으로 표시</p>
    <p><a style="color:#ffff00;font-size:150%;">&cir;</a>&nbsp;: 노란색 원 (보호 필요 지역)</p>
</div>
{% endmacro %}
"""
# 커스텀 색상
custom_css = """
<style>
.leaflet-marker-icon, .leaflet-marker-icon div {
    background-color: rgba(255, 127, 0, 0.7) !important;
    color: white !important;
}
</style>
"""
# 데이터 정리
grouped_df = df.groupby(['시군구', '피해운전자 상해정도']).size().reset_index(name='상해정도 갯수')

grouped_df['피해운전자 상해정도'] = grouped_df['피해운전자 상해정도'].astype(str)
grouped_df['상해정도 갯수'] = grouped_df['상해정도 갯수'].astype(str)
grouped_df['상해정도 정보'] = grouped_df[['피해운전자 상해정도', '상해정도 갯수']].apply(lambda x: ': '.join(x), axis=1)

grouped_df_agg = grouped_df.groupby('시군구')['상해정도 정보'].apply(lambda x: '<br>'.join(x)).reset_index()

df_all = pd.read_excel('C:\\sqlite\\mysql\\code\\AI\\total좌표.xlsx')
columns = ["시군구", "경도", "위도"]
df_all.columns = columns
first_all = df_all.groupby('시군구').first().reset_index()

first_all_merged = first_all.merge(grouped_df_agg, on='시군구', how='left')

geometry = [Point(lon, lat) for lat, lon in zip(first_all_merged['위도'], first_all_merged['경도'])]
gdf_coordinates = gpd.GeoDataFrame(first_all_merged, geometry=geometry, crs='EPSG:4326')
gdf_coordinates = gdf_coordinates[~gdf_coordinates['geometry'].is_empty]

mymap = folium.Map(location=(37.53,127), zoom_start=10, control_scale=True)
marker_cluster = MarkerCluster(
    options={
        'showCoverageOnHover': False,
        'zoomToBoundsOnClick': True,}
        ).add_to(mymap)

# 위험도 점수
# def calculate_danger_coeff(df, sg):
#     accident_weights = {
#         "경상": 0.5, 
#         "중상": 1,  
#         "부상신고": 0.25, 
#         "사망": 2.5 
#     }

#     accidents_in_location = df[df['시군구'] == sg]
#     danger_coeff = 0
#     for index, row in accidents_in_location.iterrows():
#         accident_info = row['상해정도 정보'].split('<br>')
#         for info in accident_info:
#             accident_type, num_accidents_of_type = info.split(': ')
#             num_accidents_of_type = int(num_accidents_of_type)
#             if accident_type in accident_weights:
#                 danger_coeff += num_accidents_of_type * accident_weights[accident_type]

#     total_accidents = df.shape[0]
#     danger_coeff /= total_accidents
#     # danger_score = min(100, max(0, danger_coeff * 100))
#     return danger_coeff
def calculate_danger_coeff(df, sg):
    accident_weights = {
        "경상": 0.5, 
        "중상": 1,  
        "부상신고": 0.25, 
        "사망": 2.5 
    }

    accidents_in_location = df[df['시군구'] == sg]
    danger_coeff = 0
    for index, row in accidents_in_location.iterrows():
        accident_info = row['상해정도 정보'].split('<br>')
        for info in accident_info:
            accident_type, num_accidents_of_type = info.split(': ')
            num_accidents_of_type = int(num_accidents_of_type)
            if accident_type in accident_weights:
                danger_coeff += num_accidents_of_type * accident_weights[accident_type]
        if danger_coeff >= 20:  # 위험도가 20 이상인 경우만 저장
            print(f"시군구: {sg}, 위험도: {danger_coeff}")
    return danger_coeff


#위험도 기준치
def get_color(danger_coeff):
    if danger_coeff < 5:
        return 'green'
    # elif danger_coeff < 0.01:
    #     return 'yellow'
    elif danger_coeff < 8: 
        return 'orange'
    else:
        return 'red'

for index, row in gdf_coordinates.iterrows():
    if not row['geometry'].is_empty:
        # 위험도 계산
        danger_coeff = calculate_danger_coeff(first_all_merged, row['시군구'])

        # 위험도에 따른 색상 결정
        color = get_color(danger_coeff)

        # 위험도 소수점 
        danger_coeff = round(danger_coeff, 6)

        # 위험도 색상을 한글로 바꾸기
        # color_kr = {'green': '녹색', 'yellow': '노랑색', 'orange': '주황색', 'red': '빨강색'}[color]
        color_kr = {'green': '녹색', 'orange': '주황색', 'red': '빨강색'}[color]


        latitude = row['geometry'].y
        longitude = row['geometry'].x
        # icon = folium.Icon(color=color,icon='info-sign')
        icon = folium.Icon(color=color,icon='person-falling-burst', prefix='fa')
        popup_text = f"시군구: {row['시군구']}<br>{row['상해정도 정보']}<br>위험도: {danger_coeff}<br>위험도 색상: {color_kr}"
        folium.Marker(location=[latitude, longitude], icon=icon, popup=folium.Popup(popup_text, max_width=250)).add_to(marker_cluster)


first_all_merged['상해정도 갯수'] = grouped_df['상해정도 갯수']

first_all_merged['상해정도 갯수'] = first_all_merged['상해정도 갯수'].astype(int)

# 데이터 정리
grouped_df = first_all_merged.groupby('시군구')['상해정도 갯수'].sum().reset_index()
first_all_merged = pd.merge(first_all_merged, grouped_df, on='시군구', how='left')
    
first_all_merged['danger_coeff'] = first_all_merged['시군구'].apply(lambda sg: calculate_danger_coeff(first_all_merged, sg))

danger_coeff_data = first_all_merged.groupby('시군구')['danger_coeff'].sum().reset_index()
danger_coeff_data.columns = ['SIG_KOR_NM', 'danger_coeff']

# 마커 설정
for index, row in first_all_merged.iterrows():
    latitude = row['위도']
    longitude = row['경도']
    total_injury_count = row['상해정도 갯수_y']
    # radius = total_injury_count 
    radius = np.log(total_injury_count + 1)

    # 위험도 계산
    danger_coeff = row['danger_coeff']

    # 위험도 출력
    # print(f"Danger coefficient for index {index}: {danger_coeff}")

    # 위험도에 따른 색상 가져오기
    color = get_color(danger_coeff)

    folium.CircleMarker(
        location=[latitude, longitude],
        radius=radius,
        color=color,
        fill=True,
        fill_color=color,
        fill_opacity=0.5
    ).add_to(mymap)


# 도로 출력
gdf_road = gpd.read_file('C:\\sqlite\\mysql\\code\\AI\\Mid_project\\data\\sig.shp')
gdf_road = gdf_road.set_crs(epsg=5179)
gdf_road['region_code'] = gdf_road['SIG_CD'].str[:2]
gdf_road = gdf_road[gdf_road['region_code'].isin(['11', '41'])]

accident_data = first_all_merged.groupby('시군구')['상해정도 갯수_x'].sum().reset_index()
accident_data.columns = ['EMD_KOR_NM', 'total_accidents']
accident_data['EMD_KOR_NM'] = accident_data['EMD_KOR_NM'].apply(lambda x: ' '.join(x.split()[:2]))
accident_data = accident_data.groupby('EMD_KOR_NM')['total_accidents'].sum().reset_index()

geo_data = gdf_road.__geo_interface__

# 도로 설정
folium.GeoJson(
    gdf_road,
    style_function=lambda feature: {
        'fillColor': '#000000',  # 도로 색상을 검은색으로 설정
        'color': '#000000',  # 도로 테두리 색상을 검은색으로 설정
        'weight': 0.5,  # 도로 테두리 두께를 1로 설정
        'fillOpacity': 0,  # 도로 채우기 불투명도를 1.0으로 설정
    }
).add_to(mymap)

marker_cluster = MarkerCluster().add_to(mymap)

element = Element(custom_css)
mymap.get_root().html.add_child(element)

# 어린이 보호구역 출력
gdf_protect = gpd.read_file('C:\\sqlite\\mysql\\code\\AI\\gyeonggi_protect_polygons_test.geojson')

def polygon_to_circle(polygon):
    center = polygon.centroid
    distance = center.distance(unary_union(polygon.boundary))
    return center.buffer(distance)

gdf_protect['geometry'] = gdf_protect['geometry'].apply(polygon_to_circle)

# 어린이 보호구역 설정
folium.GeoJson(
    gdf_protect,
    style_function=lambda feature: {
        'fillColor': '#0000ff',
        # 'color': '#0000ff',
        'color': 'transparent',  # 테두리 색상을 투명하게 설정
        'weight': 0.5,  # 테두리 두께를 0으로 설정
        'fillOpacity': 0.2,
    }
).add_to(mymap)

macro = MacroElement()
macro._template = Template(template)

mymap.get_root().add_child(macro)

mymap.save('C:\\sqlite\\mysql\\code\\AI\\Mid_project\\data\\file\\cartoon_map_with_injury_counts_test_1_1안.html')

# %%
# import pandas as pd
# import geopandas as gpd
# from shapely.geometry import Point

# # CSV 파일 읽기
# df = pd.read_csv('C:\\sqlite\\mysql\\code\\AI\\Mid_project\\data\\bjd_info_except_boundary.csv', encoding='cp949')

# # 'center_long'과 'center_lati' 컬럼을 사용하여 Point 객체 생성
# df['geometry'] = df.apply(lambda row: Point(row['center_long'], row['center_lati']), axis=1)

# # DataFrame을 GeoDataFrame으로 변환
# gdf = gpd.GeoDataFrame(df, geometry='geometry')

# selected_gdf = gdf[gdf['sd_nm'].isin(['서울특별시', '경기도'])]

# # GeoDataFrame을 GeoJSON으로 저장
# selected_gdf.to_file('C:\\sqlite\\mysql\\code\\AI\\Mid_project\\data\\output_test.geojson', driver='GeoJSON')

# %%
import pandas as pd
import geopandas as gpd
import folium
from shapely.geometry import Point
from folium.plugins import MarkerCluster
from shapely.geometry import Point
from shapely.ops import unary_union
from branca.element import Template, MacroElement
import numpy as np
from folium import Element

df = pd.read_excel('C:\\sqlite\\mysql\\code\\AI\\Mid_project\\data\\file\\all_test - 복사본.xlsx')

# 지도 설명 HTML
template = """
{% macro html(this, kwargs) %}
<div style="
    position: fixed; 
    top: 5px;
    right: 5px;
    width: 270px;
    height: 220px;
    z-index:9999;
    font-size:14px;
    background: #f0f0f0;
    opacity: 0.9;
    padding: 5px;
    border-radius: 10px;
    ">
    <p><a style="color:#00ff00;font-size:150%;">&block;</a>&nbsp;: 위험도 낮음 (녹색)</p>
    <p><a style="color:#8b00ff;font-size:150%;">&block;</a>&nbsp;: 위험도 높음 (보라색)</p>
    <p><a style="color:#ff0000;font-size:150%;">&block;</a>&nbsp;: 위험도 매우 높음 (빨강색)</p>
    <p><img src='https://raw.githubusercontent.com/pointhi/leaflet-color-markers/master/img/marker-icon-2x-red.png' width='25' height='41'/>&nbsp;: 마커 (사고 발생 지역)</p>
    <p><a style="color:#00FFFF;font-size:150%;">&#9679;</a>&nbsp;: 하늘색 구역 (어린이 보호 지역)</p>
</div>
<div style="
    position: fixed; 
    bottom: 5px;
    left: 5px;
    width: 250px;
    height: 40px;
    z-index:9999;
    font-size:14px;
    background: #f0f0f0;
    opacity: 0.9;
    padding: 5px;
    border-radius: 10px;
    ">
    <p><b>위험도: </b>위험도를 계산하여 색상으로 표시</p>
    <p><a style="color:#ffff00;font-size:150%;">&cir;</a>&nbsp;: 노란색 원 (보호 필요 지역)</p>
</div>
{% endmacro %}
"""
# 커스텀 색상
custom_css = """
<style>
.leaflet-marker-icon, .leaflet-marker-icon div {
    background-color: rgba(255, 127, 0, 0.7) !important;
    color: white !important;
}
</style>
"""
# 데이터 정리
grouped_df = df.groupby(['시군구', '피해운전자 상해정도']).size().reset_index(name='상해정도 갯수')

grouped_df['피해운전자 상해정도'] = grouped_df['피해운전자 상해정도'].astype(str)
grouped_df['상해정도 갯수'] = grouped_df['상해정도 갯수'].astype(str)
grouped_df['상해정도 정보'] = grouped_df[['피해운전자 상해정도', '상해정도 갯수']].apply(lambda x: ': '.join(x), axis=1)

grouped_df_agg = grouped_df.groupby('시군구')['상해정도 정보'].apply(lambda x: '<br>'.join(x)).reset_index()

df_all = pd.read_excel('C:\\sqlite\\mysql\\code\\AI\\total좌표.xlsx')
columns = ["시군구", "경도", "위도"]
df_all.columns = columns
first_all = df_all.groupby('시군구').first().reset_index()

first_all_merged = first_all.merge(grouped_df_agg, on='시군구', how='left')

geometry = [Point(lon, lat) for lat, lon in zip(first_all_merged['위도'], first_all_merged['경도'])]
gdf_coordinates = gpd.GeoDataFrame(first_all_merged, geometry=geometry, crs='EPSG:4326')
gdf_coordinates = gdf_coordinates[~gdf_coordinates['geometry'].is_empty]

mymap = folium.Map(location=(37.53,127), zoom_start=10, control_scale=True)
marker_cluster = MarkerCluster(
    options={
        'showCoverageOnHover': False,
        'zoomToBoundsOnClick': True,}
        ).add_to(mymap)

def calculate_danger_coeff(df, sg):
    accident_weights = {
        "경상": 0.5, 
        "중상": 1,  
        "부상신고": 0.25, 
        "사망": 2.5 
    }

    accidents_in_location = df[df['시군구'] == sg]
    danger_coeff = 0
    for index, row in accidents_in_location.iterrows():
        accident_info = row['상해정도 정보'].split('<br>')
        for info in accident_info:
            accident_type, num_accidents_of_type = info.split(': ')
            num_accidents_of_type = int(num_accidents_of_type)
            if accident_type in accident_weights:
                danger_coeff += num_accidents_of_type * accident_weights[accident_type]
        # if danger_coeff >= 29:  # 위험도가 20 이상인 경우
            # print(f"시군구: {sg}, 위험도: {danger_coeff}")
    return danger_coeff

#위험도 기준치
def get_color(danger_coeff):
    if danger_coeff < 7:
        return 'green'
    elif danger_coeff < 20: 
        return 'purple'
    else:
        return 'red'

for index, row in gdf_coordinates.iterrows():
    if not row['geometry'].is_empty:
        # 위험도 계산
        danger_coeff = calculate_danger_coeff(first_all_merged, row['시군구'])

        # 위험도에 따른 색상 결정
        color = get_color(danger_coeff)

        # 위험도 소수점 
        danger_coeff = round(danger_coeff, 6)

        # 위험도 색상을 한글로 바꾸기
        # color_kr = {'green': '녹색', 'yellow': '노랑색', 'orange': '주황색', 'red': '빨강색'}[color]
        color_kr = {'green': '녹색', 'purple': '보라색', 'red': '빨강색'}[color]


        latitude = row['geometry'].y
        longitude = row['geometry'].x
        # icon = folium.Icon(color=color,icon='info-sign')
        icon = folium.Icon(color=color,icon='person-falling-burst', prefix='fa')
        popup_text = f"시군구: {row['시군구']}<br>{row['상해정도 정보']}<br>위험도: {danger_coeff}<br>위험도 색상: {color_kr}"
        folium.Marker(location=[latitude, longitude], icon=icon, popup=folium.Popup(popup_text, max_width=250)).add_to(marker_cluster)


first_all_merged['상해정도 갯수'] = grouped_df['상해정도 갯수']

first_all_merged['상해정도 갯수'] = first_all_merged['상해정도 갯수'].astype(int)

# 데이터 정리
grouped_df = first_all_merged.groupby('시군구')['상해정도 갯수'].sum().reset_index()
first_all_merged = pd.merge(first_all_merged, grouped_df, on='시군구', how='left')
    
first_all_merged['danger_coeff'] = first_all_merged['시군구'].apply(lambda sg: calculate_danger_coeff(first_all_merged, sg))

danger_coeff_data = first_all_merged.groupby('시군구')['danger_coeff'].sum().reset_index()
danger_coeff_data.columns = ['SIG_KOR_NM', 'danger_coeff']

# 마커 설정
for index, row in first_all_merged.iterrows():
    latitude = row['위도']
    longitude = row['경도']
    total_injury_count = row['상해정도 갯수_y']
    # radius = total_injury_count 
    radius = np.log(total_injury_count + 1)

    # 위험도 계산
    danger_coeff = row['danger_coeff']

    # 위험도 출력
    # print(f"Danger coefficient for index {index}: {danger_coeff}")

    # 위험도에 따른 색상 가져오기
    color = get_color(danger_coeff)

    folium.CircleMarker(
        location=[latitude, longitude],
        radius=radius,
        color=color,
        fill=True,
        fill_color=color,
        fill_opacity=0.5
    ).add_to(mymap)


# 도로 출력
gdf_road = gpd.read_file('C:\\sqlite\\mysql\\code\\AI\\Mid_project\\data\\sig.shp')
gdf_road = gdf_road.set_crs(epsg=5179)
gdf_road['region_code'] = gdf_road['SIG_CD'].str[:2]
gdf_road = gdf_road[gdf_road['region_code'].isin(['11', '41'])]

accident_data = first_all_merged.groupby('시군구')['상해정도 갯수_x'].sum().reset_index()
accident_data.columns = ['EMD_KOR_NM', 'total_accidents']
accident_data['EMD_KOR_NM'] = accident_data['EMD_KOR_NM'].apply(lambda x: ' '.join(x.split()[:2]))
accident_data = accident_data.groupby('EMD_KOR_NM')['total_accidents'].sum().reset_index()

geo_data = gdf_road.__geo_interface__

# 도로 설정
folium.GeoJson(
    gdf_road,
    style_function=lambda feature: {
        'fillColor': '#000000',  # 도로 색상을 검은색으로 설정
        'color': '#000000',  # 도로 테두리 색상을 검은색으로 설정
        'weight': 0.5,  # 도로 테두리 두께를 1로 설정
        'fillOpacity': 0,  # 도로 채우기 불투명도를 1.0으로 설정
    }
).add_to(mymap)

marker_cluster = MarkerCluster().add_to(mymap)

element = Element(custom_css)
mymap.get_root().html.add_child(element)

# 어린이 보호구역 출력
gdf_protect = gpd.read_file('C:\\sqlite\\mysql\\code\\AI\\gyeonggi_protect_polygons_test.geojson')

def polygon_to_circle(polygon):
    center = polygon.centroid
    distance = center.distance(unary_union(polygon.boundary))
    return center.buffer(distance)

gdf_protect['geometry'] = gdf_protect['geometry'].apply(polygon_to_circle)

# 어린이 보호구역 설정
folium.GeoJson(
    gdf_protect,
    style_function=lambda feature: {
        'fillColor': '#00FFFF',
        # 'color': '#0000ff',
        'color': 'transparent',  # 테두리 색상을 투명하게 설정
        'weight': 0.5,  # 테두리 두께를 0으로 설정
        'fillOpacity': 0.4,
    }
).add_to(mymap)

macro = MacroElement()
macro._template = Template(template)

mymap.get_root().add_child(macro)

mymap.save('C:\\sqlite\\mysql\\code\\AI\\Mid_project\\data\\file\\cartoon_map_with_injury_counts_test_1_1안_top.html')

# %%
top_20_dangerous = first_all_merged.sort_values(by='danger_coeff', ascending=False).head(20)
print(top_20_dangerous.to_string())
# Out:
#                  시군구          경도         위도                                  상해정도 정보  상해정도 갯수_x  상해정도 갯수_y  danger_coeff
# 232      경기도 시흥시 정왕동  126.677722  37.325509    경상: 56<br>부상신고: 10<br>사망: 2<br>중상: 32          1          1         67.50
# 249  경기도 안산시 상록구 본오동  126.863217  37.293757  경상: 54<br>부상신고: 10<br>상해없음: 1<br>중상: 21          4          4         50.50
# 700    서울특별시 양천구 신정동  126.840681  37.512113    경상: 54<br>부상신고: 11<br>사망: 2<br>중상: 13          1          1         47.75
# 549    서울특별시 강서구 화곡동  126.847886  37.546698              경상: 55<br>부상신고: 5<br>중상: 17          2          2         45.75
# 144       경기도 부천시 중동  126.766976  37.490874             경상: 53<br>부상신고: 10<br>중상: 16          3          3         45.00
# 243  경기도 안산시 단원구 선부동  126.804487  37.345039     경상: 42<br>부상신고: 9<br>사망: 1<br>중상: 17          2          2         42.75
# 698     서울특별시 양천구 목동  126.868711  37.535893              경상: 44<br>부상신고: 9<br>중상: 16          1          1         40.25
# 518    서울특별시 강남구 대치동  127.050672  37.501991  경상: 45<br>부상신고: 12<br>상해없음: 1<br>중상: 14          1          1         39.50
# 699    서울특별시 양천구 신월동  126.827240  37.535532    경상: 35<br>부상신고: 10<br>사망: 1<br>중상: 15          1          1         37.50
# 112     경기도 남양주시 진접읍  127.189899  37.726396              경상: 42<br>부상신고: 3<br>중상: 15          2          2         36.75
# 117     경기도 남양주시 화도읍  127.347792  37.658233              경상: 43<br>부상신고: 4<br>중상: 14          8          8         36.50
# 198  경기도 수원시 장안구 정자동  127.000146  37.291377              경상: 40<br>부상신고: 9<br>중상: 14          5          5         36.25
# 563    서울특별시 구로구 구로동  126.888478  37.490773              경상: 46<br>부상신고: 8<br>중상: 11          1          1         36.00
# 796    서울특별시 중랑구 면목동  127.081801  37.586547              경상: 43<br>부상신고: 5<br>중상: 12          1          1         34.75
# 574    서울특별시 노원구 상계동  127.064326  37.658878              경상: 45<br>부상신고: 4<br>중상: 11          2          2         34.50
# 64       경기도 광주시 오포읍    0.000000   0.000000              경상: 33<br>부상신고: 2<br>중상: 17          4          4         34.00
# 515      경기도 화성시 향남읍  126.919423  37.130490     경상: 37<br>부상신고: 4<br>사망: 1<br>중상: 12          1          1         34.00
# 492      경기도 화성시 반송동  127.071935  37.206467              경상: 33<br>부상신고: 9<br>중상: 13          4          4         31.75
# 443      경기도 평택시 비전동  127.112120  37.000248              경상: 37<br>부상신고: 8<br>중상: 11          7          7         31.50
# 552    서울특별시 관악구 신림동  126.928349  37.486899              경상: 37<br>부상신고: 2<br>중상: 12          1          1         31.00
