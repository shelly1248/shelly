# %%
import pandas as pd

filename = r'C:\\sqlite\\mysql\\code\\AI\\Mid_project\\num-data\\경기-어린이사고20-22.csv'

df = pd.read_csv(filename)
df
# Out:
#                   사고번호               사고일시   요일               시군구    사고내용  \
# 0     2020010100100140    2020년 1월 1일 11시  수요일  경기도 안산시 단원구 대부북동    경상사고
# 1     2020010100100203    2020년 1월 1일 15시  수요일   경기도 안산시 단원구 신길동    경상사고
# 2     2020010100100255    2020년 1월 1일 17시  수요일      경기도 의정부시 녹양동    중상사고
# 3     2020010100100265    2020년 1월 1일 18시  수요일       경기도 이천시 신둔면    중상사고
# 4     2020010100100353    2020년 1월 1일 22시  수요일      경기도 남양주시 별내동    경상사고
# ...                ...                ...  ...               ...     ...
# 7521  2022123000100514  2022년 12월 30일 18시  금요일   경기도 수원시 영통구 이의동    경상사고
# 7522  2022123000100570  2022년 12월 30일 19시  금요일       경기도 의왕시 월암동    경상사고
# 7523  2022123000100585  2022년 12월 30일 19시  금요일       경기도 파주시 당하동    중상사고
# 7524  2022123000100599  2022년 12월 30일 20시  금요일       경기도 안성시 대덕면  부상신고사고
# 7525  2022123100100337  2022년 12월 31일 16시  토요일   경기도 고양시 덕양구 도내동    중상사고
#
#       사망자수  중상자수  경상자수  부상신고자수         사고유형  ... 기상상태             도로형태  \
# 0        0     0     4       0   차대차 - 측면충돌  ...   맑음         단일로 - 기타
# 1        0     0     3       0  차대차 - 후진중충돌  ...   맑음       교차로 - 교차로안
# 2        0     5     5       0   차대차 - 정면충돌  ...   맑음      교차로 - 교차로부근
# 3        0     1     0       0   차대사람 - 횡단중  ...   맑음       교차로 - 교차로안
# 4        0     0     3       0     차대차 - 기타  ...   맑음       교차로 - 교차로안
# ...    ...   ...   ...     ...          ...  ...  ...              ...
# 7521     0     0     1       2     차대차 - 추돌  ...   맑음          기타 - 기타
# 7522     0     0     3       0   차대차 - 정면충돌  ...   맑음       교차로 - 교차로안
# 7523     0     1     8       0     차대차 - 추돌  ...   맑음  단일로 - 지하차도(도로)내
# 7524     0     0     0       2    차대사람 - 기타  ...   맑음      교차로 - 교차로부근
# 7525     0     1     0       0   차대사람 - 횡단중  ...   맑음      교차로 - 교차로부근
#
#      가해운전자 차종 가해운전자 성별 가해운전자 연령 가해운전자 상해정도 피해운전자 차종 피해운전자 성별 피해운전자 연령  \
# 0          승용        남      31세       상해없음       승용        남      43세
# 1          승용        남      35세       상해없음       승용        남      37세
# 2          승합        남      28세       상해없음       승용        남      29세
# 3          승용        남      72세       상해없음      보행자        남       7세
# 4          승용        남      74세       상해없음       승용        여      39세
# ...       ...      ...      ...        ...      ...      ...      ...
# 7521       승용        남      63세       상해없음       승용        남      40세
# 7522       승용        남      67세       상해없음       승용        여      29세
# 7523       승용        남      35세         경상       승용        남      43세
# 7524       승용        남      36세       상해없음      보행자        남      42세
# 7525       승용        남      68세       상해없음      보행자        남       9세
#
#      피해운전자 상해정도
# 0            경상
# 1            경상
# 2            중상
# 3            중상
# 4            경상
# ...         ...
# 7521       부상신고
# 7522         경상
# 7523         경상
# 7524       부상신고
# 7525         중상
#
# [7526 rows x 22 columns]

# %%
df = df[df['피해운전자 연령'] <= '12세']

# %%
filename_2 = 'C:\\sqlite\\mysql\\code\\AI\\Mid_project\\num-data\\경기-어린이보호구역사고20-22.csv'

df_2 = pd.read_csv(filename_2)
df_2
# Out:
#                  사고번호               사고일시   요일                시군구  사고내용  사망자수  \
# 0    2020010300100617    2020년 1월 3일 23시  금요일  경기도 고양시 일산동구 정발산동  경상사고     0
# 1    2020010800100407    2020년 1월 8일 17시  수요일    경기도 용인시 수지구 죽전동  중상사고     0
# 2    2020011000100510   2020년 1월 10일 19시  금요일    경기도 용인시 처인구 고림동  경상사고     0
# 3    2020011100100256   2020년 1월 11일 13시  토요일        경기도 김포시 풍무동  중상사고     0
# 4    2020011500100200   2020년 1월 15일 11시  수요일        경기도 양주시 광적면  경상사고     0
# ..                ...                ...  ...                ...   ...   ...
# 994  2022122700100458  2022년 12월 27일 18시  화요일       경기도 의정부시 민락동  중상사고     0
# 995  2022122800100285  2022년 12월 28일 14시  수요일        경기도 화성시 우정읍  경상사고     0
# 996  2022122800100306  2022년 12월 28일 14시  수요일       경기도 남양주시 호평동  경상사고     0
# 997  2022122900100396  2022년 12월 29일 17시  목요일        경기도 화성시 장지동  중상사고     0
# 998  2022123100100319  2022년 12월 31일 16시  토요일        경기도 오산시 고현동  경상사고     0
#
#      중상자수  경상자수  부상신고자수        사고유형  ... 기상상태            도로형태 가해운전자 차종  \
# 0       0     1       0  차대차 - 측면충돌  ...   맑음      교차로 - 교차로안       승용
# 1       1     0       0   차대사람 - 기타  ...   맑음        단일로 - 기타       승용
# 2       0     1       0  차대차 - 측면충돌  ...   맑음     교차로 - 교차로부근       승용
# 3       1     4       0    차대차 - 추돌  ...   맑음      교차로 - 교차로안       이륜
# 4       0     1       0    차대차 - 기타  ...   맑음        단일로 - 기타       화물
# ..    ...   ...     ...         ...  ...  ...             ...      ...
# 994     1     0       0    차대차 - 기타  ...   맑음        단일로 - 기타       승용
# 995     0     2       0  차대차 - 측면충돌  ...   맑음        단일로 - 기타       화물
# 996     0     1       0  차대사람 - 횡단중  ...   맑음  교차로 - 교차로횡단보도내       이륜
# 997     1     0       0  차대사람 - 횡단중  ...   맑음  교차로 - 교차로횡단보도내       승용
# 998     0     1       0    차대차 - 기타  ...   맑음      교차로 - 교차로안       승용
#
#     가해운전자 성별 가해운전자 연령 가해운전자 상해정도 피해운전자 차종 피해운전자 성별 피해운전자 연령 피해운전자 상해정도
# 0          남      63세       상해없음       이륜        여      51세         경상
# 1          여      48세       상해없음      보행자        여      10세         중상
# 2          남      21세       상해없음       이륜        남      39세         경상
# 3          여      53세         중상       승용        남      49세         경상
# 4          남      36세       상해없음       화물        남      53세         경상
# ..       ...      ...        ...      ...      ...      ...        ...
# 994        남      50세       상해없음       이륜        남      41세         중상
# 995        남      65세       상해없음       승용        남      29세         경상
# 996        남      52세       상해없음      보행자        남      13세         경상
# 997        여      53세       상해없음      보행자        남       7세         중상
# 998        남      21세       상해없음       이륜        남      27세         경상
#
# [999 rows x 22 columns]

# %%
df_2 = df_2[df_2['피해운전자 연령'] <= '12세']

# %%
df_2
# Out:
#                  사고번호               사고일시   요일              시군구    사고내용  사망자수  \
# 1    2020010800100407    2020년 1월 8일 17시  수요일  경기도 용인시 수지구 죽전동    중상사고     0
# 5    2020011500100395   2020년 1월 15일 17시  수요일      경기도 군포시 금정동    경상사고     0
# 17   2020020800100306    2020년 2월 8일 15시  토요일  경기도 성남시 수정구 태평동    경상사고     0
# 25   2020021800100683   2020년 2월 18일 20시  화요일      경기도 파주시 목동동    중상사고     0
# 48   2020032700100440   2020년 3월 27일 18시  금요일      경기도 포천시 소흘읍    중상사고     0
# ..                ...                ...  ...              ...     ...   ...
# 961  2022111600100648  2022년 11월 16일 20시  수요일     경기도 의정부시 용현동    경상사고     0
# 970  2022112500100339  2022년 11월 25일 16시  금요일  경기도 안양시 동안구 평촌동  부상신고사고     0
# 971  2022112600100233  2022년 11월 26일 13시  토요일      경기도 부천시 원종동    경상사고     0
# 978  2022120500100217   2022년 12월 5일 14시  월요일  경기도 성남시 수정구 태평동    중상사고     0
# 990  2022121900100489  2022년 12월 19일 19시  월요일      경기도 구리시 교문동  부상신고사고     0
#
#      중상자수  경상자수  부상신고자수               사고유형  ... 기상상태            도로형태 가해운전자 차종  \
# 1       1     0       0          차대사람 - 기타  ...   맑음        단일로 - 기타       승용
# 5       0     1       0          차대사람 - 기타  ...   맑음     교차로 - 교차로부근       승용
# 17      0     1       0       차대사람 - 보도통행중  ...   맑음  교차로 - 교차로횡단보도내       승용
# 25      1     0       0         차대사람 - 횡단중  ...   맑음      교차로 - 교차로안       승용
# 48      1     0       0         차대사람 - 횡단중  ...   맑음        단일로 - 기타       승용
# ..    ...   ...     ...                ...  ...  ...             ...      ...
# 961     0     1       0       차대사람 - 보도통행중  ...   흐림      교차로 - 교차로안       승용
# 970     0     0       1         차대차 - 측면충돌  ...   맑음        단일로 - 기타       승용
# 971     0     1       0  차대사람 - 길가장자리구역통행중  ...   맑음        단일로 - 기타       승용
# 978     1     0       0          차대사람 - 기타  ...   맑음  교차로 - 교차로횡단보도내       이륜
# 990     0     0       1           차대차 - 기타  ...   맑음      교차로 - 교차로안       이륜
#
#     가해운전자 성별 가해운전자 연령 가해운전자 상해정도 피해운전자 차종 피해운전자 성별 피해운전자 연령 피해운전자 상해정도
# 1          여      48세       상해없음      보행자        여      10세         중상
# 5          여      56세       상해없음      보행자        여      12세         경상
# 17         여      27세       상해없음      보행자        여      10세         경상
# 25         여      26세       상해없음      보행자        남      12세         중상
# 48         여      46세       상해없음      보행자        남      11세         중상
# ..       ...      ...        ...      ...      ...      ...        ...
# 961        남      24세       상해없음      보행자        여      11세         경상
# 970        남      54세       상해없음      자전거        남      10세       부상신고
# 971        남      66세       상해없음      보행자        여      12세         경상
# 978        여      62세       상해없음      보행자        남      11세         중상
# 990        남      27세       부상신고      자전거        남      12세       상해없음
#
# [135 rows x 22 columns]

# %%
df['어린이보호구역'] = 0
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_21884\2100499040.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['어린이보호구역'] = 0

# %%
df_2['어린이보호구역'] = 1
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_21884\296492547.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2['어린이보호구역'] = 1

# %%
# df와 df_2를 '사고번호'를 기준으로 병합
df_concat = pd.concat([df, df_2])

# %%
# '사고번호' 열의 값이 중복되는 행을 찾음
duplicated = df_concat.duplicated('사고번호', keep=False)

# %%
# 중복되는 '사건번호'를 가진 행의 '어린이보호구역' 값을 1로 설정
df_concat.loc[duplicated, '어린이보호구역'] = 1

# %%
# 중복되지 않는 '사건번호'를 가진 행의 '어린이보호구역' 값을 0으로 설정
df_concat.loc[~duplicated, '어린이보호구역'] = 0

# %%
df_concat['피해운전자 연령'] = df_concat['피해운전자 연령'].str.replace('세','')

# %%
df_concat.isnull().sum()
# Out:
# 사고번호          0
# 사고일시          0
# 요일            0
# 시군구           0
# 사고내용          0
# 사망자수          0
# 중상자수          0
# 경상자수          0
# 부상신고자수        0
# 사고유형          0
# 법규위반          0
# 노면상태          0
# 기상상태          0
# 도로형태          0
# 가해운전자 차종      0
# 가해운전자 성별      0
# 가해운전자 연령      0
# 가해운전자 상해정도    0
# 피해운전자 차종      0
# 피해운전자 성별      0
# 피해운전자 연령      0
# 피해운전자 상해정도    0
# 어린이보호구역       0
# dtype: int64

# %%
df_concat
# Out:
#                  사고번호               사고일시   요일              시군구    사고내용  사망자수  \
# 8    2020010200100276    2020년 1월 2일 15시  목요일      경기도 안성시 석정동    경상사고     0
# 29   2020010500100156    2020년 1월 5일 12시  일요일  경기도 용인시 기흥구 청덕동  부상신고사고     0
# 38   2020010600100091    2020년 1월 6일 08시  월요일      경기도 부천시 춘의동    경상사고     0
# 49   2020010700100340    2020년 1월 7일 15시  화요일      경기도 시흥시 은행동    중상사고     0
# 59   2020010800100401    2020년 1월 8일 17시  수요일  경기도 안산시 단원구 선부동    중상사고     0
# ..                ...                ...  ...              ...     ...   ...
# 961  2022111600100648  2022년 11월 16일 20시  수요일     경기도 의정부시 용현동    경상사고     0
# 970  2022112500100339  2022년 11월 25일 16시  금요일  경기도 안양시 동안구 평촌동  부상신고사고     0
# 971  2022112600100233  2022년 11월 26일 13시  토요일      경기도 부천시 원종동    경상사고     0
# 978  2022120500100217   2022년 12월 5일 14시  월요일  경기도 성남시 수정구 태평동    중상사고     0
# 990  2022121900100489  2022년 12월 19일 19시  월요일      경기도 구리시 교문동  부상신고사고     0
#
#      중상자수  경상자수  부상신고자수               사고유형  ...            도로형태 가해운전자 차종  \
# 8       0     1       0          차대사람 - 기타  ...        단일로 - 기타       승용
# 29      0     0       1         차대사람 - 횡단중  ...        단일로 - 기타       승용
# 38      0     1       0         차대사람 - 횡단중  ...  교차로 - 교차로횡단보도내       승용
# 49      1     0       0          차대사람 - 기타  ...        단일로 - 기타       승용
# 59      1     0       0         차대사람 - 횡단중  ...      교차로 - 교차로안       승용
# ..    ...   ...     ...                ...  ...             ...      ...
# 961     0     1       0       차대사람 - 보도통행중  ...      교차로 - 교차로안       승용
# 970     0     0       1         차대차 - 측면충돌  ...        단일로 - 기타       승용
# 971     0     1       0  차대사람 - 길가장자리구역통행중  ...        단일로 - 기타       승용
# 978     1     0       0          차대사람 - 기타  ...  교차로 - 교차로횡단보도내       이륜
# 990     0     0       1           차대차 - 기타  ...      교차로 - 교차로안       이륜
#
#     가해운전자 성별 가해운전자 연령 가해운전자 상해정도 피해운전자 차종 피해운전자 성별 피해운전자 연령 피해운전자 상해정도 어린이보호구역
# 8          남      55세       상해없음      보행자        여       10         경상       0
# 29         남      48세       상해없음      보행자        남       12       부상신고       0
# 38         여      51세       상해없음      보행자        남       12         경상       0
# 49         여      74세       상해없음      보행자        여       12         중상       0
# 59         남      56세       상해없음      보행자        남       12         중상       0
# ..       ...      ...        ...      ...      ...      ...        ...     ...
# 961        남      24세       상해없음      보행자        여       11         경상       1
# 970        남      54세       상해없음      자전거        남       10       부상신고       1
# 971        남      66세       상해없음      보행자        여       12         경상       1
# 978        여      62세       상해없음      보행자        남       11         중상       1
# 990        남      27세       부상신고      자전거        남       12       상해없음       0
#
# [1146 rows x 23 columns]

# %%
df_concat.to_excel('C:\\sqlite\\mysql\\code\\AI\\Mid_project\\data경기_2022.xlsx')
